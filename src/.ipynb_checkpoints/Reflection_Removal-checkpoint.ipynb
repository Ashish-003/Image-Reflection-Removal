# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
ghost_gray_image = cv2.cvtColor(cv2.imread("ghost.png"), cv2.COLOR_BGR2GRAY)
plt.imshow(ghost_gray_image, cmap="gray")
plt.title("Ghost Gray Image")
plt.show()

# %%
plt.imshow(ghost_gray_image[400:520, 625:750], cmap="gray")
plt.title("User Input Patch")
plt.show()

# %%
def reflection_removal(gray_img, endpoints):
    return

# %%
reflection_removed_gray_image = reflection_removal(ghost_gray_image, np.array({"x_min": 625, "x_max": 750, "y_min": 400, "y_max": 520}))
plt.imshow(reflection_removed_gray_image, cmap="gray")
plt.title("Reflection Removed Gray Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5820898d3a13> in <module>()
#       1 reflection_removed_gray_image = reflection_removal(ghost_gray_image, np.array([{"x": 625, "y": 400}, {"x": 750, "y": 520}]))
# ----> 2 plt.imshow(reflection_removed_gray_image, cmap="gray")
#       3 plt.title("Reflection Removed Gray Image")
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ...
